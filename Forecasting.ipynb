# %% [raw]
# Forecast the CocaCola prices and Airlines Passengers data set. Prepare a document for each model explaining
# how many dummy variables you have created and RMSE value for each model. Finally which model you will use for
# Forecasting.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
df = pd.read_excel("CocaCola_Sales_Rawdata.xlsx")
df.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
df.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %%
df['Sales'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Sales'].skew()
# Out:
# 0.6301623195471511

# %% [markdown]
# # Applying Transformation

# %% [markdown]
# # Root Transformation

# %%
df['Sq_Sales']=df['Sales']**1/4
df['Sq_Sales'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Sq_Sales'].skew()
# Out:
# 0.6301623195471511

# %% [markdown]
# # Logarithmic Transformation

# %%
df['log_Sales']=np.log(df['Sales']+0.01)
df['log_Sales'].skew()
# Out:
# 0.17216678797834095

# %%
df['log_Sales'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Reciprocal Transformation

# %%
df['rec_Sales']=1/(df['Sales']+0.01)
df['rec_Sales'].skew()
# Out:
# 0.31119758635892203

# %%
df['rec_Sales'].hist()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#   Quarter       Sales   Sq_Sales  log_Sales  rec_Sales
# 0   Q1_86  108.426687  27.106672   4.686166   0.009222
# 1   Q2_86  140.310062  35.077516   4.943926   0.007127
# 2   Q3_86  158.362812  39.590703   5.064952   0.006314
# 3   Q4_86  134.685187  33.671297   4.903014   0.007424
# 4   Q1_87   96.738687  24.184672   4.572117   0.010336

# %%
df=df.drop(columns=['Sales','Sq_Sales','rec_Sales'],axis=1)
df.head()
# Out:
#   Quarter  log_Sales
# 0   Q1_86   4.686166
# 1   Q2_86   4.943926
# 2   Q3_86   5.064952
# 3   Q4_86   4.903014
# 4   Q1_87   4.572117

# %% [markdown]
# # Data Visualization

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as  sns
sns.boxplot(data =df)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import lag_plot
lag_plot(df['log_Sales'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#   Quarter  log_Sales
# 0   Q1_86   4.686166
# 1   Q2_86   4.943926
# 2   Q3_86   5.064952
# 3   Q4_86   4.903014
# 4   Q1_87   4.572117

# %%
df['quarter'] = 0
for i in range(42):
    p=df['Quarter'][i]
    df['quarter'][i]=p[0:2]
# Out:
# <ipython-input-16-bca6adf2edda>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'][i]=p[0:2]
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.head()
# Out:
#   Quarter        Sales quarter
# 0   Q1_86  1734.827000      Q1
# 1   Q2_86  2244.960999      Q2
# 2   Q3_86  2533.804993      Q3
# 3   Q4_86  2154.962997      Q4
# 4   Q1_87  1547.818996      Q1

# %%
df['quarter'].value_counts()
# Out:
# Q2    11
# Q1    11
# Q3    10
# Q4    10
# Name: quarter, dtype: int64

# %%
df_dummies=pd.DataFrame(pd.get_dummies(df['quarter']),columns=['Q1','Q2','Q3','Q4'])
cc=pd.concat([df,df_dummies],axis= 1)
cc.head()
# Out:
#   Quarter        Sales quarter  Q1  Q2  Q3  Q4
# 0   Q1_86  1734.827000      Q1   1   0   0   0
# 1   Q2_86  2244.960999      Q2   0   1   0   0
# 2   Q3_86  2533.804993      Q3   0   0   1   0
# 3   Q4_86  2154.962997      Q4   0   0   0   1
# 4   Q1_87  1547.818996      Q1   1   0   0   0

# %%
cc['t'] = np.arange(1,43)
cc['t_squared'] = cc['t']**2
cc["Sales_log"] =np.log(df['Sales'])

# %%
cc.head()
# Out:
#   Quarter        Sales quarter  Q1  Q2  Q3  Q4  t  t_squared  Sales_log
# 0   Q1_86  1734.827000      Q1   1   0   0   0  1          1   7.458663
# 1   Q2_86  2244.960999      Q2   0   1   0   0  2          4   7.716443
# 2   Q3_86  2533.804993      Q3   0   0   1   0  3          9   7.837477
# 3   Q4_86  2154.962997      Q4   0   0   0   1  4         16   7.675529
# 4   Q1_87  1547.818996      Q1   1   0   0   0  5         25   7.344602

# %%
train =cc.head(32)
test =cc.tail(10)

# %%
df['Sales'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Building

# %%
from sklearn.metrics import mean_squared_error

# %%
# Linear Model
linear_model =smf.ols("Sales~t",data =train).fit()
linear_pred = pd.Series(linear_model.predict(test['t']))
linear_rmse =np.sqrt(mean_squared_error(np.array(test['Sales']),np.array(linear_pred)))
linear_rmse
# Out:
# 752.9233932767115

# %%
#Quadratic Model
quad_model =smf.ols("Sales~t+t_squared",data=train).fit()
quad_pred = pd.Series(quad_model.predict(test[['t','t_squared']]))
quad_rmse =np.sqrt(mean_squared_error(np.array(test['Sales']),np.array(quad_pred)))
quad_rmse
# Out:
# 457.73573554072897

# %%
# Exponential model
exp_model  =smf.ols("Sales_log~t",data=train).fit()
exp_pred =pd.Series(exp_model.predict(test['t']))
exp_rmse =np.sqrt(mean_squared_error(np.array(test['Sales']),np.array(exp_pred)))
exp_rmse
# Out:
# 4387.940544839098

# %%
data = {"MODEL":pd.Series(["rmse_linear","rmse_exp","rmse_quad"]),
        "RMSE_Values":pd.Series([linear_rmse,exp_rmse,quad_rmse,])}
table_rmse=pd.DataFrame(data)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#          MODEL  RMSE_Values
# 2    rmse_quad   457.735736
# 0  rmse_linear   752.923393
# 1     rmse_exp  4387.940545

# %% [markdown]
# ## Using ARIMA model

# %%
data = pd.read_excel("CocaCola_Sales_Rawdata.xlsx",header=0,index_col=0, parse_dates=True)
data.head()
# Out:
#                Sales
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996

# %%
#separate out a validation dataset
split_point = len(data) - 7
dataset_cc, validation_cc = data[0:split_point], data[split_point:]
print('Dataset_cc %d, Validation_cc %d' % (len(dataset_cc), len(validation_cc)))
# Out:
# Dataset_cc 35, Validation_cc 7

# %%
dataset_cc.to_csv('dataset_cc.csv', header=False)
validation_cc.to_csv('validation_cc.csv', header=False)

# %%
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from math import sqrt

train = read_csv('dataset_cc.csv', header=None, index_col=0, parse_dates=True, squeeze=True)

train
# Out:
# 0
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996
# Q2_87    2104.411995
# Q3_87    2014.362999
# Q4_87    1991.746998
# Q1_88    1869.049999
# Q2_88    2313.631996
# Q3_88    2128.320000
# Q4_88    2026.828999
# Q1_89    1910.603996
# Q2_89    2331.164993
# Q3_89    2206.549995
# Q4_89    2173.967995
# Q1_90    2148.278000
# Q2_90    2739.307999
# Q3_90    2792.753998
# Q4_90    2556.009995
# Q1_91    2480.973999
# Q2_91    3039.522995
# Q3_91    3172.115997
# Q4_91    2879.000999
# Q1_92    2772.000000
# Q2_92    3550.000000
# Q3_92    3508.000000
# Q4_92    3243.859993
# Q1_93    3056.000000
# Q2_93    3899.000000
# Q3_93    3629.000000
# Q4_93    3373.000000
# Q1_94    3352.000000
# Q2_94    4342.000000
# Q3_94    4461.000000
# Name: 1, dtype: float64

# %%
X = train.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]

# %% [markdown]
# ## Validation

# %%
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    yhat = history[-1]
    predictions.append(yhat)
# observation
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
# report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# Out:
# >Predicted=2148.278, Expected=2739.308
# >Predicted=2739.308, Expected=2792.754
# >Predicted=2792.754, Expected=2556.010
# >Predicted=2556.010, Expected=2480.974
# >Predicted=2480.974, Expected=3039.523
# >Predicted=3039.523, Expected=3172.116
# >Predicted=3172.116, Expected=2879.001
# >Predicted=2879.001, Expected=2772.000
# >Predicted=2772.000, Expected=3550.000
# >Predicted=3550.000, Expected=3508.000
# >Predicted=3508.000, Expected=3243.860
# >Predicted=3243.860, Expected=3056.000
# >Predicted=3056.000, Expected=3899.000
# >Predicted=3899.000, Expected=3629.000
# >Predicted=3629.000, Expected=3373.000
# >Predicted=3373.000, Expected=3352.000
# >Predicted=3352.000, Expected=4342.000
# >Predicted=4342.000, Expected=4461.000
# RMSE: 434.401

# %% [markdown]
# ### ARIMA model has the least RMSE value. Hence ARIMA model will be used for Forecasting

# %% [raw]
# 2)Forecast the Airlines Passengers data set. Prepare a document for each model explaining.
# How many dummy variables you have created and RMSE value for each model.
# Finally which model you will use for Forecasting.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel("Airlines+Data.xlsx")
data.head()
# Out:
#        Month  Passengers
# 0 1995-01-01         112
# 1 1995-02-01         118
# 2 1995-03-01         132
# 3 1995-04-01         129
# 4 1995-05-01         121

# %%
data['Passengers'].skew()
# Out:
# 0.6373753552984904

# %% [markdown]
# # Applying Transformation

# %% [markdown]
# # Root Transformation

# %%
data['Sq_Passengers']=data['Passengers']**1/4
data['Sq_Passengers'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Sq_Passengers'].skew()
# Out:
# 0.6373753552984904

# %% [markdown]
# # Log Transformation

# %%
data['log_Passengers']=np.log(data['Passengers']+0.01)
data['log_Passengers'].hist()
# Out:
# <AxesSubplot:>

# %%
data['log_Passengers'].skew()
# Out:
# 0.011113897354867827

# %% [markdown]
# # Reciprocal Transformation

# %%
data['rec_Passengers']=1/(data['Passengers']+0.01)
data['rec_Passengers'].hist()
# Out:
# <AxesSubplot:>

# %%
data['rec_Passengers'].skew()
# Out:
# 0.5502840880222355

# %%
data['Month']=pd.to_datetime(data['Month'], infer_datetime_format=True)
data=data.set_index(['Month'])

# %%
data.head()
# Out:
#             Passengers
# Month
# 1995-01-01         112
# 1995-02-01         118
# 1995-03-01         132
# 1995-04-01         129
# 1995-05-01         121

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Month")
plt.ylabel("Number of Air Passengers")
plt.plot(data)

# %%
rolmean=data.rolling(window=12).mean()
rolstd=data.rolling(window=12).std()
print(rolmean.head(15))
print(rolstd.head(15))
# Out:
#             Passengers
# Month
# 1995-01-01         NaN
# 1995-02-01         NaN
# 1995-03-01         NaN
# 1995-04-01         NaN
# 1995-05-01         NaN
# 1995-06-01         NaN
# 1995-07-01         NaN
# 1995-08-01         NaN
# 1995-09-01         NaN
# 1995-10-01         NaN
# 1995-11-01         NaN
# 1995-12-01  126.666667
# 1996-01-01  126.916667
# 1996-02-01  127.583333
# 1996-03-01  128.333333
#             Passengers
# Month
# 1995-01-01         NaN
# 1995-02-01         NaN
# 1995-03-01         NaN
# 1995-04-01         NaN
# 1995-05-01         NaN
# 1995-06-01         NaN
# 1995-07-01         NaN
# 1995-08-01         NaN
# 1995-09-01         NaN
# 1995-10-01         NaN
# 1995-11-01         NaN
# 1995-12-01   13.720147
# 1996-01-01   13.453342
# 1996-02-01   13.166475
# 1996-03-01   13.686977

# %%
plt.figure(figsize=(15,10))
actual=plt.plot(data, color='red', label='Actual')
mean_6=plt.plot(rolmean, color='green', label='Rolling Mean') 
std_6=plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
from statsmodels.tsa.stattools import adfuller
print('Dickey-Fuller Test: ')
dftest=adfuller(data['Passengers'], autolag='AIC')
dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Dickey-Fuller Test:
# Test Statistic           1.340248
# p-value                  0.996825
# Lags Used               12.000000
# No. of Obs              83.000000
# Critical Value (1%)     -3.511712
# Critical Value (5%)     -2.897048
# Critical Value (10%)    -2.585713
# dtype: float64

# %%
plt.figure(figsize=(15,8))
data_log=np.log(data)
plt.plot(data_log)

# %%
plt.figure(figsize=(15,8))
MAvg=data_log.rolling(window=12).mean()
MStd=data_log.rolling(window=12).std()
plt.plot(data_log)
plt.plot(MAvg, color='blue')

# %%
data_log_diff=data_log-MAvg
data_log_diff.head(12)
# Out:
#             Passengers
# Month
# 1995-01-01         NaN
# 1995-02-01         NaN
# 1995-03-01         NaN
# 1995-04-01         NaN
# 1995-05-01         NaN
# 1995-06-01         NaN
# 1995-07-01         NaN
# 1995-08-01         NaN
# 1995-09-01         NaN
# 1995-10-01         NaN
# 1995-11-01         NaN
# 1995-12-01   -0.065494

# %%
data_log_diff=data_log_diff.dropna()
data_log_diff.head()
# Out:
#             Passengers
# Month
# 1995-12-01   -0.065494
# 1996-01-01   -0.093449
# 1996-02-01   -0.007566
# 1996-03-01    0.099416
# 1996-04-01    0.052142

# %%
def stationarity(timeseries):
    
    rolmean=timeseries.rolling(window=12).mean()
    rolstd=timeseries.rolling(window=12).std()
    
    plt.figure(figsize=(15,8))
    actual=plt.plot(timeseries, color='red', label='Actual')
    mean_6=plt.plot(rolmean, color='green', label='Rolling Mean') 
    std_6=plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    print('Dickey-Fuller Test: ')
    dftest=adfuller(timeseries['Passengers'], autolag='AIC')
    dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
stationarity(data_log_diff)
# Out:
# Dickey-Fuller Test:
# Test Statistic          -1.910930
# p-value                  0.326937
# Lags Used               12.000000
# No. of Obs              72.000000
# Critical Value (1%)     -3.524624
# Critical Value (5%)     -2.902607
# Critical Value (10%)    -2.588679
# dtype: float64

# %%
plt.figure(figsize=(15,8))
exp_data=data_log.ewm(halflife=12, min_periods=0, adjust=True).mean()
plt.plot(data_log)
plt.plot(exp_data, color='black')

# %%
exp_data_diff=data_log-exp_data
stationarity(exp_data_diff)
# Out:
# Dickey-Fuller Test:
# Test Statistic          -2.835036
# p-value                  0.053441
# Lags Used               12.000000
# No. of Obs              83.000000
# Critical Value (1%)     -3.511712
# Critical Value (5%)     -2.897048
# Critical Value (10%)    -2.585713
# dtype: float64

# %%
plt.figure(figsize=(15,8))
data_shift=data_log-data_log.shift()
plt.plot(data_shift)

# %%
data_shift=data_shift.dropna()
stationarity(data_shift)
# Out:
# Dickey-Fuller Test:
# Test Statistic          -2.670823
# p-value                  0.079225
# Lags Used               12.000000
# No. of Obs              82.000000
# Critical Value (1%)     -3.512738
# Critical Value (5%)     -2.897490
# Critical Value (10%)    -2.585949
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp=seasonal_decompose(data_log)

trend=decomp.trend
seasonal=decomp.seasonal
residual=decomp.resid

plt.subplot(411)
plt.plot(data_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
decomp_data=residual
decomp_data=decomp_data.dropna()
stationarity(decomp_data)
# Out:
# Dickey-Fuller Test:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# C:\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#
# C:\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         if res is None:
# --> 649             raise ParserError("Unknown string format: %s", timestr)
#     650
#
# ParserError: Unknown string format: Passengers
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     663             try:
# --> 664                 key = self._maybe_cast_for_get_loc(key)
#     665             except ValueError as err:
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in _maybe_cast_for_get_loc(self, key)
#     691         # needed to localize naive datetimes or dates (GH 35690)
# --> 692         key = Timestamp(key)
#     693         if key.tzinfo is None:
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-656404df39df> in <module>
#       1 decomp_data=residual
#       2 decomp_data=decomp_data.dropna()
# ----> 3 stationarity(decomp_data)
#
# <ipython-input-52-4cd71b3fe576> in stationarity(timeseries)
#      13
#      14     print('Dickey-Fuller Test: ')
# ---> 15     dftest=adfuller(timeseries['Passengers'], autolag='AIC')
#      16     dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])
#      17     for key,value in dftest[4].items():
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     664                 key = self._maybe_cast_for_get_loc(key)
#     665             except ValueError as err:
# --> 666                 raise KeyError(key) from err
#     667
#     668         elif isinstance(key, timedelta):
#
# KeyError: 'Passengers'

# %%
from statsmodels.tsa.stattools import acf, pacf

lag_acf=acf(data_shift, nlags=20)
lag_pacf=pacf(data_shift, nlags=20, method='ols')

plt.figure(figsize=(15,8))
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='green')
plt.axhline(y=-1.96/np.sqrt(len(data_shift)),linestyle='--',color='green')
plt.axhline(y=1.96/np.sqrt(len(data_shift)),linestyle='--',color='green')
plt.title('Autocorrelation Function')

plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='green')
plt.axhline(y=-1.96/np.sqrt(len(data_shift)),linestyle='--',color='green')
plt.axhline(y=1.96/np.sqrt(len(data_shift)),linestyle='--',color='green')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %% [markdown]
# # ARIMA model

# %%
from statsmodels.tsa.arima_model import ARIMA

plt.figure(figsize=(15,8))
model=ARIMA(data_log, order=(2,1,2))
results=model.fit(disp=-1)
plt.plot(data_shift)
plt.plot(results.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results.fittedvalues-data_shift['Passengers'])**2))
print('plotting ARIMA model')
# Out:
# plotting ARIMA model

# %%
predictions=pd.Series(results.fittedvalues, copy=True)
print(predictions.head())
# Out:
# Month
# 1995-02-01    0.011035
# 1995-03-01    0.012803
# 1995-04-01    0.011279
# 1995-05-01   -0.007585
# 1995-06-01   -0.009599
# dtype: float64

# %%
predictions_cum_sum=predictions.cumsum()
print(predictions_cum_sum.head())
# Out:
# Month
# 1995-02-01    0.011035
# 1995-03-01    0.023838
# 1995-04-01    0.035117
# 1995-05-01    0.027531
# 1995-06-01    0.017932
# dtype: float64

# %%
predictions_log=pd.Series(data_log['Passengers'])
predictions_log=predictions_log.add(predictions_cum_sum,fill_value=0)
predictions_log.head()
# Out:
# Month
# 1995-01-01    4.718499
# 1995-02-01    4.781719
# 1995-03-01    4.906639
# 1995-04-01    4.894929
# 1995-05-01    4.823322
# dtype: float64

# %%
redictions_ARIMA=np.exp(pd.Series(data_log['Passengers']))
plt.figure(figsize=(15,8))
plt.plot(data)
plt.plot(predictions_ARIMA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-d2dfbf0a7461> in <module>
#       2 plt.figure(figsize=(15,8))
#       3 plt.plot(data)
# ----> 4 plt.plot(predictions_ARIMA)
#
# NameError: name 'predictions_ARIMA' is not defined

# %%
rcParams['figure.figsize']=20,10
results.plot_predict(1,204)
x=results.forecast(steps=120)

# %%
results.forecast(steps=120)
# Out:
# (array([5.77909416, 5.83569098, 5.88142252, 5.91101434, 5.9250268 ,
#         5.92780223, 5.92512156, 5.92226196, 5.92281855, 5.92833996,
#         5.93860415, 5.9522546 , 5.96751695, 5.98278744, 5.99698528,
#         6.00965651, 6.02088436, 6.0310922 , 6.04082441, 6.05056823,
#         6.06064844, 6.07119786, 6.08218641, 6.09348208, 6.10491792,
#         6.11634593, 6.12766857, 6.13884706, 6.14989199, 6.16084449,
#         6.17175574, 6.18267068, 6.19361858, 6.20461075, 6.21564354,
#         6.22670413, 6.23777683, 6.24884803, 6.25990891, 6.27095621,
#         6.28199116, 6.29301776, 6.30404079, 6.31506441, 6.32609125,
#         6.33712226, 6.34815701, 6.35919428, 6.3702326 , 6.38127069,
#         6.39230779, 6.4033436 , 6.41437828, 6.4254122 , 6.43644582,
#         6.44747951, 6.45851351, 6.46954791, 6.48058266, 6.49161763,
#         6.50265269, 6.51368772, 6.52472265, 6.53575747, 6.54679218,
#         6.55782682, 6.56886144, 6.57989606, 6.59093072, 6.60196541,
#         6.61300013, 6.62403488, 6.63506963, 6.64610438, 6.65713912,
#         6.66817385, 6.67920857, 6.69024328, 6.70127799, 6.7123127 ,
#         6.72334741, 6.73438213, 6.74541685, 6.75645158, 6.7674863 ,
#         6.77852102, 6.78955574, 6.80059046, 6.81162518, 6.8226599 ,
#         6.83369462, 6.84472934, 6.85576406, 6.86679878, 6.8778335 ,
#         6.88886822, 6.89990294, 6.91093766, 6.92197238, 6.9330071 ,
#         6.94404182, 6.95507654, 6.96611127, 6.97714599, 6.98818071,
#         6.99921543, 7.01025015, 7.02128487, 7.03231959, 7.04335431,
#         7.05438903, 7.06542375, 7.07645847, 7.08749319, 7.09852791,
#         7.10956263, 7.12059735, 7.13163207, 7.14266679, 7.15370151]),
#  array([0.08380566, 0.10161562, 0.10467548, 0.10471912, 0.10684041,
#         0.11045014, 0.11334767, 0.11465608, 0.11489227, 0.1148983 ,
#         0.11508911, 0.11541024, 0.11566995, 0.1157868 , 0.11580705,
#         0.11580783, 0.11582611, 0.11585597, 0.11587969, 0.1158901 ,
#         0.11589178, 0.1158919 , 0.11589372, 0.11589659, 0.11589883,
#         0.11589981, 0.11589996, 0.11589997, 0.11590014, 0.11590039,
#         0.11590058, 0.11590065, 0.11590066, 0.11590067, 0.11590069,
#         0.11590072, 0.11590074, 0.11590075, 0.11590075, 0.11590075,
#         0.11590075, 0.11590075, 0.11590075, 0.11590075, 0.11590075,
#         0.11590075, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590076, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590076, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590076, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590076, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590076, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590076, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590076, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590076, 0.11590076, 0.11590076, 0.11590076, 0.11590076,
#         0.11590077, 0.11590077, 0.11590077, 0.11590077, 0.11590077,
#         0.11590077, 0.11590077, 0.11590077, 0.11590077, 0.11590077,
#         0.11590077, 0.11590077, 0.11590077, 0.11590077, 0.11590077,
#         0.11590077, 0.11590077, 0.11590077, 0.11590077, 0.11590077,
#         0.11590077, 0.11590077, 0.11590077, 0.11590077, 0.11590077,
#         0.11590077, 0.11590077, 0.11590077, 0.11590077, 0.11590077]),
#  array([[5.61483808, 5.94335023],
#         [5.63652804, 6.03485393],
#         [5.67626235, 6.08658268],
#         [5.70576864, 6.11626005],
#         [5.71562344, 6.13443017],
#         [5.71132392, 6.14428053],
#         [5.70296421, 6.14727891],
#         [5.69754018, 6.14698374],
#         [5.69763383, 6.14800326],
#         [5.70314342, 6.1535365 ],
#         [5.71303365, 6.16417465],
#         [5.72605467, 6.17845452],
#         [5.74080801, 6.19422589],
#         [5.75584949, 6.20972539],
#         [5.77000764, 6.22396293],
#         [5.78267734, 6.23663569],
#         [5.79386936, 6.24789936],
#         [5.80401866, 6.25816573],
#         [5.81370439, 6.26794443],
#         [5.82342781, 6.27770866],
#         [5.83350472, 6.28779216],
#         [5.84405392, 6.2983418 ],
#         [5.85503889, 6.30933393],
#         [5.86632894, 6.32063523],
#         [5.87776038, 6.33207545],
#         [5.88918648, 6.34350537],
#         [5.90050882, 6.35482833],
#         [5.91168729, 6.36600683],
#         [5.9227319 , 6.37705208],
#         [5.93368391, 6.38800507],
#         [5.94459478, 6.3989167 ],
#         [5.95550957, 6.40983178],
#         [5.96645745, 6.4207797 ],
#         [5.97744962, 6.43177188],
#         [5.98848237, 6.44280471],
#         [5.9995429 , 6.45386535],
#         [6.01061556, 6.46493811],
#         [6.02168673, 6.47600932],
#         [6.03274761, 6.48707021],
#         [6.04379491, 6.49811751],
#         [6.05482986, 6.50915246],
#         [6.06585645, 6.52017906],
#         [6.07687949, 6.5312021 ],
#         [6.08790311, 6.54222572],
#         [6.09892994, 6.55325255],
#         [6.10996095, 6.56428356],
#         [6.12099571, 6.57531832],
#         [6.13203298, 6.58635559],
#         [6.14307129, 6.5973939 ],
#         [6.15410938, 6.608432  ],
#         [6.16514648, 6.6194691 ],
#         [6.17618229, 6.63050491],
#         [6.18721697, 6.64153959],
#         [6.19825089, 6.65257351],
#         [6.20928451, 6.66360713],
#         [6.2203182 , 6.67464082],
#         [6.2313522 , 6.68567483],
#         [6.2423866 , 6.69670922],
#         [6.25342134, 6.70774397],
#         [6.26445631, 6.71877894],
#         [6.27549137, 6.729814  ],
#         [6.2865264 , 6.74084903],
#         [6.29756134, 6.75188397],
#         [6.30859615, 6.76291878],
#         [6.31963086, 6.77395349],
#         [6.3306655 , 6.78498814],
#         [6.34170012, 6.79602275],
#         [6.35273475, 6.80705738],
#         [6.3637694 , 6.81809203],
#         [6.37480409, 6.82912673],
#         [6.38583882, 6.84016145],
#         [6.39687356, 6.8511962 ],
#         [6.40790831, 6.86223095],
#         [6.41894306, 6.8732657 ],
#         [6.4299778 , 6.88430044],
#         [6.44101253, 6.89533517],
#         [6.45204725, 6.90636989],
#         [6.46308196, 6.9174046 ],
#         [6.47411667, 6.92843931],
#         [6.48515138, 6.93947402],
#         [6.49618609, 6.95050874],
#         [6.50722081, 6.96154345],
#         [6.51825553, 6.97257818],
#         [6.52929025, 6.9836129 ],
#         [6.54032498, 6.99464762],
#         [6.5513597 , 7.00568235],
#         [6.56239442, 7.01671707],
#         [6.57342914, 7.02775179],
#         [6.58446386, 7.03878651],
#         [6.59549858, 7.04982123],
#         [6.6065333 , 7.06085595],
#         [6.61756802, 7.07189067],
#         [6.62860274, 7.08292539],
#         [6.63963746, 7.09396011],
#         [6.65067218, 7.10499483],
#         [6.6617069 , 7.11602955],
#         [6.67274162, 7.12706427],
#         [6.68377634, 7.13809899],
#         [6.69481106, 7.14913371],
#         [6.70584578, 7.16016843],
#         [6.7168805 , 7.17120315],
#         [6.72791522, 7.18223787],
#         [6.73894994, 7.1932726 ],
#         [6.74998465, 7.20430732],
#         [6.76101937, 7.21534204],
#         [6.77205409, 7.22637676],
#         [6.78308881, 7.23741148],
#         [6.79412353, 7.2484462 ],
#         [6.80515825, 7.25948092],
#         [6.81619297, 7.27051564],
#         [6.82722769, 7.28155036],
#         [6.83826241, 7.29258508],
#         [6.84929713, 7.3036198 ],
#         [6.86033185, 7.31465452],
#         [6.87136657, 7.32568924],
#         [6.88240129, 7.33672396],
#         [6.89343601, 7.34775868],
#         [6.90447073, 7.3587934 ],
#         [6.91550545, 7.36982812],
#         [6.92654017, 7.38086284]]))
